# %%
print("Hello world")
print("name",2)
#print("you are good in english")

print('''ali
ahmad 
tayyab
adeel''')

print(3)

print(3,2,1)

print(3+2+1)

print("name ",3+3)


A = 22
B = 33
C = A + B
print(C)

age = 22
name = "tayyab afzaal"
print(name,":",age)
print(age)

A,B,C = "Orange","Banana","Apple"
print(A,B,C)

Fruit = ["Orange","Banana","Apple"]
print(Fruit)
print(type(Fruit))

X=range(10)
print(X)
print(type(X))

Student={
    "Name":"tayyab afzaal",
    "Reg#":"MC-BSCS-243-009",
    "CGPA":"3.75",
    "Email":"tayyab@example.com",
    "Phone":"123-456-7890",
    "Address":"123 Main St, Multan, Pakistan",
}
print(Student)
# Out:
# Hello world
# name 2
# ali
# ahmad
# tayyab
# adeel
# 3
# 3 2 1
# 6
# name  6
# 55
# tayyab afzaal : 22
# 22
# Orange Banana Apple
# ['Orange', 'Banana', 'Apple']
# <class 'list'>
# range(0, 10)
# <class 'range'>
# {'Name': 'tayyab afzaal', 'Reg#': 'MC-BSCS-243-009', 'CGPA': '3.75', 'Email': 'tayyab@example.com', 'Phone': '123-456-7890', 'Address': '123 Main St, Multan, Pakistan'}
